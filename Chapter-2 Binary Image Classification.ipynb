# %% [markdown]
# # Binary Image Classification
#
# We cover the following recipes:
# - Exploring the dataset
# - Creating a custom dataset
# - Splitting the dataset
# - Transforming the dataset
# - Creating dataloaders
# - Building the classification model
# - Defining the loss function
# - Defining the optimizer
# - Training and evaluation of the model
# - Deploying the model
# - Model inference on test data

# %% [markdown]
# # Exploring the dataset

# %% [markdown]
# ### 1. Let's begin by reading train_labels.csv and printing out its head:

# %%
import pandas as pd

path2csv = "./data/histopathologic-cancer-detection/train_labels.csv"
labels_df = pd.read_csv(path2csv)
labels_df.head()
# Out:
#                                          id  label
# 0  f38a6374c348f90b587e046aac6079959adf3835      0
# 1  c18f2d887b7ae4f6742ee445113fa1aef383ed77      1
# 2  755db6279dae599ebb4d39a9123cce439965282d      0
# 3  bc3f0c64fb968ff4a8bd33af6971ecae77c75e08      0
# 4  068aba587a4950175d04c680d38943fd488d6a9d      0

# %% [markdown]
# ### 2. Let's count the number of normal and malignant cases:

# %%
print(labels_df['label'].value_counts())
# Out:
# 0    130908
# 1     89117
# Name: label, dtype: int64

# %% [markdown]
# - Normal = 0
# - Malignant = 1

# %% [markdown]
# ### 3. Let's look at a histogram of the labels

# %%
# %matplotlib inline
labels_df['label'].hist()

# %% [markdown]
# ### 4. Let's visualize a few images that have a positive label. A positive label shows that the center 32x32 region of an image contains at least one pixel of tumor tissue. First, we import the required packages:

# %%
import matplotlib.pylab as plt
from PIL import Image, ImageDraw
import numpy as np
import os
# %matplotlib inline

# %% [markdown]
# Then, we get the IDs of the malignant images:

# %%
# get ids for malignant images
malignant_ids = labels_df.loc[labels_df['label']==1]['id'].values

# %% [markdown]
# Define the path to data:

# %%
# data is stored here
path2train = "./data/histopathologic-cancer-detection/train/"

# %% [markdown]
# Next, we define a flag to show images in grayscale or color mode:

# %%
# show images in grayscale, if you want color change it to True
color = True

# %% [markdown]
# Next, we set the figure sizes:

# %%
plt.rcParams['figure.figsize'] = (10.0, 10.0)
plt.subplots_adjust(wspace=0, hspace=0)
nrows, ncols = 3,3

# %% [markdown]
# Next, we display the images:

# %%
for i, id_ in enumerate(malignant_ids[:nrows * ncols]):
    full_filenames = os.path.join(path2train, id_ + '.tif')
    
    # load image
    img = Image.open(full_filenames)
    
    # draw a 32*32 rectangle
    draw = ImageDraw.Draw(img)
    draw.rectangle(((32, 32), (64, 64)), outline="green")
    plt.subplot(nrows, ncols, i+1)
    
    if color is True:
        plt.imshow(np.array(img))
    else:
        plt.imshow(np.array(img)[:, :, 0], cmap="gray")
    plt.axis('off')

# %% [markdown]
# ### 5. Let's also get the image's shape and minimum and maximum pixel values:

# %%
print("image shape:", np.array(img).shape)
print("pixel values range from %s to %s" % (np.min(img), np.max(img)))
# Out:
# image shape: (96, 96, 3)
# pixel values range from 0 to 255

# %% [markdown]
# # Creating a custom dataset
#
# Traditional method: Load all images into NumPy arrays. Not good for large datasets.

# %% [markdown]
# ### 1. Let's create a PyTorch custom dataset for our data:

# %%
# Load the required packages

from PIL import Image
import torch
from torch.utils.data import Dataset
import pandas as pd
import torchvision.transforms as transforms
import os

# %% [markdown]
# Don't forget to fix the random seed for reproducibility:

# %%
# fix torch random seed
torch.manual_seed(0)

# %% [markdown]
# Define the histoCancerDataset class:

# %%
class HistoCancerDataset(Dataset):
    def __init__(self, data_dir, transform, data_type="train"):
        # path tom images
        path2data = os.path.join(data_dir, data_type)
        
        # get a list of images
        filenames = os.listdir(path2data)
        
        # get the full path to images
        self.full_filenames = [os.path.join(path2data, f) for f in filenames]
        
        # labels are in a csv file named train_labels.csv
        csv_filename = data_type + "_labels.csv"
        path2csv_labels = os.path.join(data_dir, csv_filename)
        labels_df = pd.read_csv(path2csv_labels)
        
        # set data frame index to id
        labels_df.set_index("id", inplace=True)
        
        # obtain labels from data frame
        self.labels = [labels_df.loc[filename[:-4]].values[0] for 
                      filename in filenames]
        
        self.transform = transform
        
    def __len__(self):
        # return size of dataset
        return len(self.full_filenames)
    
    def __getitem__(self, idx):
        # open image, apply transforms and return with label
        image = Image.open(self.full_filenames[idx]) # PIL image
        image = self.transform(image)
        return image, self.labels[idx]

# %% [markdown]
# ### 2. Next, we will define a simple transformation that only converts a PIL image into PyTorch tensors. Later, we will expand this:

# %%
import torchvision.transforms as transforms
data_transformer = transforms.Compose([transforms.ToTensor()])

# %% [markdown]
# ### 3. Then, we will define an object of the custom dataset for the train folder:

# %%
data_dir = "./data/histopathologic-cancer-detection/"
histo_dataset = HistoCancerDataset(data_dir, data_transformer,
                                   "train")
print(len(histo_dataset))
# Out:
# 220025

# %% [markdown]
# ### 4. Next, we will load an image using the custom dataset:

# %%
# load an image
img, label = histo_dataset[9]
print(img.shape, torch.min(img), torch.max(img))
# Out:
# torch.Size([3, 96, 96]) tensor(0.) tensor(1.)

# %% [markdown]
# ToTensor() converts a PIL image into the range[0, 255] to torch.FloatTensor of shape(CxHxW) in the range[0.0, 1.0].

# %% [markdown]
# ## Splitting the dataset

# %% [markdown]
# ### 1. Let's split histo_dataset:

# %%
from torch.utils.data import random_split

len_histo = len(histo_dataset)
len_train = int(0.8 * len_histo)
len_val = len_histo - len_train

train_ds, val_ds = random_split(histo_dataset, [len_train, len_val])

print("train dataset length:", len(train_ds))
print("validation dataset length:", len(val_ds))
# Out:
# train dataset length: 176020
# validation dataset length: 44005

# %% [markdown]
# ### 2. Then, we can get an image from the training dataset:

# %%
for x,y in train_ds:
    print(x.shape, y)
    break
# Out:
# torch.Size([3, 96, 96]) 0

# %% [markdown]
# ### 3. We will also get an image from the validation dataset:

# %%
for x,y in val_ds:
    print(x.shape, y)
    break
# Out:
# torch.Size([3, 96, 96]) 1

# %% [markdown]
# ### 4. Let's display a few samples from train_ds:

# %%
# Import the required packages
from torchvision import utils
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
np.random.seed(0)

# %% [markdown]
# Define a helper function to show an image:

# %%
def show(img, y, color=False):
    # convert tensor to numpy array
    np_img = img.numpy()
    
    # convert to H*W*C shape
    np_img_tr = np.transpose(np_img, (1, 2, 0))
    
    if color==False:
        np_img_tr = np_img_tr[:, :, 0]
        plt.imshow(np_img_tr, interpolation='nearest', cmap='gray')
    else:
        # display images
        plt.imshow(np_img_tr, interpolation='nearest')
    plt.title("label: " + str(y))

# %% [markdown]
# Create a grid of sample images:

# %%
grid_size = 4
rnd_inds = np.random.randint(0, len(train_ds), grid_size)
print("image indices:", rnd_inds)

x_grid_train = [train_ds[i][0] for i in rnd_inds]
y_grid_train = [train_ds[i][1] for i in rnd_inds]

x_grid_train = utils.make_grid(x_grid_train, nrow=4, padding=2)
print(x_grid_train.shape)
# Out:
# image indices: [ 43567 173685 117952 152315]
# torch.Size([3, 100, 394])

# %% [markdown]
# Call the helper function to display the grid:

# %%
plt.rcParams['figure.figsize'] = (10.0, 5)
show(x_grid_train, y_grid_train)

# %% [markdown]
# ### 5. We can also show a few samples from val_ds:

# %%
grid_size = 4
rnd_inds = np.random.randint(0, len(val_ds), grid_size)
print("image indices:", rnd_inds)
x_grid_val = [val_ds[i][0] for i in range(grid_size)]
y_grid_val = [val_ds[i][1] for i in range(grid_size)]

x_grid_val = utils.make_grid(x_grid_val, nrow=4, padding=2)
print(x_grid_val.shape)

show(x_grid_val, y_grid_val)
# Out:
# image indices: [30403 32103 41993 20757]
# torch.Size([3, 100, 394])

# %% [markdown]
# ## Transforming the data

# %% [markdown]
# ### 1. First, let's define the following transformation for the training dataset:

# %%
train_transformer = transforms.Compose([
                        transforms.RandomHorizontalFlip(p=0.5),
                        transforms.RandomVerticalFlip(p=0.5),
                        transforms.RandomRotation(45),
                        transforms.RandomResizedCrop(96,
                                                     scale=(0.8, 1.0),
                                                     ratio=(1.0, 1.0)),
                        transforms.ToTensor()
])

# %% [markdown]
# ### 2. For the validation dataset, we don't need any augmentation. So, we only convert the images into tensors in the transforms function:

# %%
val_transformer = transforms.Compose([transforms.ToTensor()])

# %% [markdown]
# ### 3. After defining the transformations, we overwrite the transform functions of train_ds and val_ds:

# %%
# overwrite the transform functions
train_ds.transform = train_transformer
val_ds.transform = val_transformer

# %% [markdown]
# ## Creating dataloaders

# %% [markdown]
# ### 1. First, let's define two dataloaders for the datasets:

# %%
from torch.utils.data import DataLoader
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=64, shuffle=False)

# %% [markdown]
# ### 2. Then, we get a data batch from the training dataloader:

# %%
# extract a batch from training data
for x, y in train_dl:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([32, 3, 96, 96])
# torch.Size([32])

# %% [markdown]
# ### 3. Next, we get a data batch from the validation dataloader:

# %%
for x, y in val_dl:
    print(x.shape)
    print(y.shape)
    break
# Out:
# torch.Size([64, 3, 96, 96])
# torch.Size([64])

# %% [markdown]
# ## Building the classification model

# %% [markdown]
# ### 1. First, let's create dumb baselines for the validation dataset.

# %% [markdown]
# First, we will get the labels for the validation dataset:

# %%
# get labels for validation dataset
y_val = [y for _,y in val_ds]

# %% [markdown]
# Next, we will define a function to calculate the classification accuracy:

# %%
def accuracy(labels, out):
    return np.sum(out==labels)/float(len(labels))

# %% [markdown]
# Then, we will calculate a dumb baseline for all-zero predictions:

# %%
# accuracy all zero predictions
acc_all_zeros = accuracy(y_val, np.zeros_like(y_val))
print("accuracy all zero prediction: %.2f" %acc_all_zeros)
# Out:
# accuracy all zero prediction: 0.59

# %% [markdown]
# Next, we will calculate a dumb baseline for all-one predictions:

# %%
# accuracy all ones predictions
acc_all_ones = accuracy(y_val, np.ones_like(y_val))

print("accuracy all one predictions: %.2f" %acc_all_ones)
# Out:
# accuracy all one predictions: 0.41

# %% [markdown]
# Next, we will calculate a dumb baseline for random predictions:

# %%
# accuracy random predictions
acc_random = accuracy(y_val, np.random.randint(2, size=len(y_val)))

print("accuracy random prediction: %.2f" %acc_random)
# Out:
# accuracy random prediction: 0.50

# %% [markdown]
# ### 2. Let's implement a helper function to calculate the output of a CNN layer:

# %%
import torch.nn as nn
import numpy as np

# %%
def find_conv2d_out_shape(h_in, w_in, conv, pool=2):
    # get conv arguments
    kernel_size = conv.kernel_size
    stride = conv.stride
    padding = conv.padding
    dilation = conv.dilation
    
    # Ref: https://pytorch.org/docs/stable/nn.html
    h_out = np.floor((h_in + 2 * padding[0] -
                      dilation[0] * 
                      (kernel_size[0] - 1) - 1)/stride[0] + 1)
    
    w_out = np.floor((w_in + 2 * padding[1] - 
                     dilation[1] * (kernel_size[1] - 1) - 1) / 
                    stride[1] + 1)
    
    if pool:
        h_out = h_out / pool
        w_out = w_out / pool
        
    return int(h_out), int(w_out)

# %%
# example
conv1 = nn.Conv2d(3, 8, kernel_size=3)
h, w = find_conv2d_out_shape(96, 96, conv1)
print(h, w)
# Out:
# 47 47

# %% [markdown]
# ### 3. Next, we will implement the CNN model.

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Net(nn.Module):
    def __init__(self, params):
        super(Net, self).__init__()
        c_in, h_in, w_in = params["input_shape"]
        init_f = params["initial_filters"]
        num_fc1 = params["num_fc1"]
        num_classes = params["num_classes"]
        self.dropout_rate = params["dropout_rate"]
        
        self.conv1 = nn.Conv2d(c_in, init_f, kernel_size=3)
        h, w = find_conv2d_out_shape(h_in, w_in, self.conv1)
        self.conv2 = nn.Conv2d(init_f, 2*init_f, kernel_size=3)
        h, w = find_conv2d_out_shape(h, w, self.conv2)
        self.conv3 = nn.Conv2d(2*init_f, 4*init_f, kernel_size=3)
        h, w = find_conv2d_out_shape(h, w, self.conv3)
        
        self.conv4 = nn.Conv2d(4*init_f, 8*init_f, kernel_size=3)
        h, w = find_conv2d_out_shape(h, w, self.conv4)
        
        # compute the flatten size
        self.num_flatten = h * w * 8 * init_f
        self.fc1 = nn.Linear(self.num_flatten, num_fc1)
        self.fc2 = nn.Linear(num_fc1, num_classes)
        
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv3(x))
        x = F.max_pool2d(x, 2, 2)
        x = F.relu(self.conv4(x))
        x = F.max_pool2d(x, 2, 2)
        x = x.view(-1, self.num_flatten)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, self.dropout_rate, training=self.training)
        x = self.fc2(x)
        return F.log_softmax(x, dim=1)

# %% [markdown]
# ### 4. Then, we will construct an object of the Net class:

# %%
# dict to define model parameters
params_model = {
                "input_shape": (3, 96, 96),
                "initial_filters": 8,
                "num_fc1": 100,
                "dropout_rate": 0.25,
                "num_classes": 2,
}

# create model
cnn_model = Net(params_model)

# %% [markdown]
# ### 5. Move the model to a cuda device if one's available:

# %%
# move model to cuda/gpu device
if torch.cuda.is_available():
    device = torch.device("cuda")
    cnn_model = cnn_model.to(device)

# %% [markdown]
# ### 6. Print the model:

# %%
print(cnn_model)
# Out:
# Net(
#   (conv1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=2, bias=True)
# )

# %% [markdown]
# ### 7. Verify the model device:

# %%
print(next(cnn_model.parameters()).device)
# Out:
# cuda:0

# %% [markdown]
# ### 8. Let's get a summary of the model:

# %%
from torchsummary import summary
summary(cnn_model, input_size=(3, 96, 96), device=device.type)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 94, 94]             224
#             Conv2d-2           [-1, 16, 45, 45]           1,168
#             Conv2d-3           [-1, 32, 20, 20]           4,640
#             Conv2d-4             [-1, 64, 8, 8]          18,496
#             Linear-5                  [-1, 100]         102,500
#             Linear-6                    [-1, 2]             202
# ================================================================
# Total params: 127,230
# Trainable params: 127,230
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.11
# Forward/backward pass size (MB): 0.92
# Params size (MB): 0.49
# Estimated Total Size (MB): 1.51
# ----------------------------------------------------------------

# %% [markdown]
# It is interesting to see that the fully connected layer has the highest number of parameters, which is not efficient. Therefore, state-of-the-art deep learning models eliminate fully connected layers in their design.

# %% [markdown]
# ## Defining the loss function
#
# The standard loss function for classification tasks is cross-entropy or log-loss. However, when defining the loss function, we need to consider the number of model outputs and their activation functions.

# %% [markdown]
# ### 1. First, let's define the loss function, as follows:

# %%
loss_func = nn.NLLLoss(reduction="sum")

# %% [markdown]
# ### 2. Next, we will use the loss in an example:

# %%
# fix random seed
torch.manual_seed(0)

n, c = 8, 2
y = torch.randn(n, c, requires_grad=True)
ls_f = nn.LogSoftmax(dim=1)
y_out = ls_f(y)
print(y_out.shape)

target = torch.randint(c, size=(n,))
print(target.shape)

loss = loss_func(y_out, target)
print(loss.item())
# Out:
# torch.Size([8, 2])
# torch.Size([8])
# 5.266995429992676

# %% [markdown]
# ### 3. Then, we will compute the gradients of the loss with respect to y:

# %%
loss.backward()
print(y.data)
# Out:
# tensor([[-1.1258, -1.1524],
#         [-0.2506, -0.4339],
#         [ 0.8487,  0.6920],
#         [-0.3160, -2.1152],
#         [ 0.3223, -1.2633],
#         [ 0.3500,  0.3081],
#         [ 0.1198,  1.2377],
#         [ 1.1168, -0.2473]])

# %% [markdown]
# ## Defining the optimizer

# %% [markdown]
# ### 1. First, let's define an object of the Adam optimizer with a learning rate of 3e-4:

# %%
from torch import optim
opt = optim.Adam(cnn_model.parameters(), lr=3e-4)

# %% [markdown]
# ### 2. We can read the current value of the learning rate using the following function:

# %%
# get learning rate
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']
    
current_lr = get_lr(opt)
print('current lr={}'.format(current_lr))
# Out:
# current lr=0.0003

# %% [markdown]
# ### 3. Next, we will define a learning scheduler using the ReduceLROnPlateau method:

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

# define learning rate scheduler
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.5,
                                 patience=20, verbose=1)

# %% [markdown]
# ### 4. Then, we will learn how the learning rate schedule works using the following example:

# %%
for i in range(100):
    lr_scheduler.step(1)
# Out:
# Epoch    22: reducing learning rate of group 0 to 1.5000e-04.
# Epoch    43: reducing learning rate of group 0 to 7.5000e-05.
# Epoch    64: reducing learning rate of group 0 to 3.7500e-05.
# Epoch    85: reducing learning rate of group 0 to 1.8750e-05.

# %% [markdown]
# The mode argument defines whether the metric quantity is increasing or decreasing during training. For instance, if we monitor the loss value, we set mode="min". If we monitor the accuracy, we should set mode="max".

# %% [markdown]
# ## Training and evaluation of the model

# %% [markdown]
# ### 1. First, let's develop a helper function to count the number of correct predictions per data batch:

# %%
def metrics_batch(output, target):
    # get output class
    pred = output.argmax(dim=1, keepdim=True)
    # compare output class with target class
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects

# %% [markdown]
# ### 2. Then, we will develop a helper function to compute the loss value per batch of data:

# %%
def loss_batch(loss_func, output, target, opt=None):
    loss = loss_func(output, target)
    with torch.no_grad():
        metric_b = metrics_batch(output, target)
        
    if opt is not None:
        opt.zero_grad()
        loss.backward()
        opt.step()
    return loss.item(), metric_b

# %% [markdown]
# ### 3. Next, we develop a helper function to compute the loss value and the performance metric for the entire dataset, also called an epoch.

# %%
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)
    
    for xb, yb in dataset_dl:
        # move batch to device
        xb = xb.to(device)
        yb = yb.to(device)
        
        # get model output
        output = model(xb)
        
        # get loss per batch
        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)
        
        # update running loss
        running_loss = running_loss + loss_b
        
        # update running metric
        if metric_b is not None:
            running_metric = running_metric + metric_b
            
        # break the loop in case of sanity check
        if sanity_check is True:
            break
            
    # average loss value
    loss = running_loss / float(len_data)
    
    # average metric value
    metric = running_metric / float(len_data)
    
    return loss, metric

# %% [markdown]
# ### 4. Let's develop the train_val function in the following code blocks:

# %%
def train_val(model, params):
    # extract model parameters
    num_epochs = params["num_epochs"]
    loss_func = params["loss_func"]
    opt = params["optimizer"]
    train_dl = params["train_dl"]
    val_dl = params["val_dl"]
    sanity_check = params["sanity_check"]
    lr_scheduler = params["lr_scheduler"]
    path2weights = params["path2weights"]
    
    # history of loss values in each epoch
    loss_history = {
        "train": [],
        "val": [],
    }
    # history of metric values in each epoch
    metric_history = {
        "train": [],
        "val": [],
    }
    
    # a deep copy of weights for the best performing model
    best_model_wts = copy.deepcopy(model.state_dict())
    
    # initialize best loss to a large value
    best_loss = float('inf')
    
    # main loop
    for epoch in range(num_epochs):
        # get current learning rate
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr={}'.format(epoch, 
                                                  num_epochs - 1,
                                                  current_lr))
        # train model on training dataset:
        model.train()
        train_loss, train_metric = loss_epoch(model,
                                              loss_func,
                                              train_dl,
                                              sanity_check,
                                              opt)
        
        # collect loss and metric for training dataset
        loss_history["train"].append(train_loss)
        metric_history["train"].append(train_metric)
        
        # evaluate model on validation dataset
        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model,
                                              loss_func,
                                              val_dl,
                                              sanity_check)
            
        # collect loss and metric for validation dataset
        loss_history["val"].append(val_loss)
        metric_history["val"].append(val_metric)

        # store best model
        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            # store weights into a local file
            torch.save(model.state_dict(), path2weights)
            print("Copied best model weights!")
                
        # learning rate schedule
        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print("Loading best model weights!")
            model.load_state_dict(best_model_wts)
                
        print("train_loss: %.6f, dev loss: %.6f, accuracy: %.2f" %(train_loss, val_loss, 100*val_metric))
        print("-"*10)
            
    # load best model weights
    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %% [markdown]
# ### 5. Let's set the sanity_check flag to True and run the code.

# %%
import copy
loss_func = nn.NLLLoss(reduction="sum")
opt = optim.Adam(cnn_model.parameters(), lr=3e-4)
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.5,
                                 patience=20, verbose=1)

# %%
# define the training parameters and call the train_val helper function

params_train = {
    "num_epochs": 100,
    "optimizer": opt,
    "loss_func": loss_func,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": True,
    "lr_scheduler": lr_scheduler,
    "path2weights": "./models/weights.pt",
}

# train and validate the model
cnn_model, loss_hist, metric_hist = train_val(cnn_model, params_train)
# Out:
# Epoch 0/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000072, dev loss: 0.000730, accuracy: 0.12
# ----------
# Epoch 1/99, current lr=0.0003
# train_loss: 0.000094, dev loss: 0.000748, accuracy: 0.12
# ----------
# Epoch 2/99, current lr=0.0003
# train_loss: 0.000126, dev loss: 0.000746, accuracy: 0.12
# ----------
# Epoch 3/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000123, dev loss: 0.000719, accuracy: 0.12
# ----------
# Epoch 4/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000091, dev loss: 0.000706, accuracy: 0.12
# ----------
# Epoch 5/99, current lr=0.0003
# train_loss: 0.000079, dev loss: 0.000711, accuracy: 0.12
# ----------
# Epoch 6/99, current lr=0.0003
# train_loss: 0.000117, dev loss: 0.000706, accuracy: 0.12
# ----------
# Epoch 7/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000076, dev loss: 0.000706, accuracy: 0.12
# ----------
# Epoch 8/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000079, dev loss: 0.000704, accuracy: 0.12
# ----------
# Epoch 9/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000084, dev loss: 0.000702, accuracy: 0.12
# ----------
# Epoch 10/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000090, dev loss: 0.000697, accuracy: 0.12
# ----------
# Epoch 11/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000085, dev loss: 0.000692, accuracy: 0.12
# ----------
# Epoch 12/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000105, dev loss: 0.000690, accuracy: 0.12
# ----------
# Epoch 13/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000080, dev loss: 0.000688, accuracy: 0.12
# ----------
# Epoch 14/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000094, dev loss: 0.000686, accuracy: 0.12
# ----------
# Epoch 15/99, current lr=0.0003
# train_loss: 0.000094, dev loss: 0.000689, accuracy: 0.12
# ----------
# Epoch 16/99, current lr=0.0003
# train_loss: 0.000099, dev loss: 0.000690, accuracy: 0.12
# ----------
# Epoch 17/99, current lr=0.0003
# train_loss: 0.000083, dev loss: 0.000687, accuracy: 0.12
# ----------
# Epoch 18/99, current lr=0.0003
# train_loss: 0.000060, dev loss: 0.000698, accuracy: 0.12
# ----------
# Epoch 19/99, current lr=0.0003
# train_loss: 0.000085, dev loss: 0.000744, accuracy: 0.12
# ----------
# Epoch 20/99, current lr=0.0003
# train_loss: 0.000093, dev loss: 0.000775, accuracy: 0.11
# ----------
# Epoch 21/99, current lr=0.0003
# train_loss: 0.000104, dev loss: 0.000779, accuracy: 0.11
# ----------
# Epoch 22/99, current lr=0.0003
# train_loss: 0.000106, dev loss: 0.000717, accuracy: 0.12
# ----------
# Epoch 23/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000080, dev loss: 0.000669, accuracy: 0.12
# ----------
# Epoch 24/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000079, dev loss: 0.000653, accuracy: 0.12
# ----------
# Epoch 25/99, current lr=0.0003
# train_loss: 0.000107, dev loss: 0.000660, accuracy: 0.12
# ----------
# Epoch 26/99, current lr=0.0003
# train_loss: 0.000099, dev loss: 0.000672, accuracy: 0.12
# ----------
# Epoch 27/99, current lr=0.0003
# train_loss: 0.000097, dev loss: 0.000666, accuracy: 0.12
# ----------
# Epoch 28/99, current lr=0.0003
# train_loss: 0.000091, dev loss: 0.000653, accuracy: 0.12
# ----------
# Epoch 29/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000119, dev loss: 0.000646, accuracy: 0.12
# ----------
# Epoch 30/99, current lr=0.0003
# train_loss: 0.000119, dev loss: 0.000662, accuracy: 0.12
# ----------
# Epoch 31/99, current lr=0.0003
# train_loss: 0.000103, dev loss: 0.000677, accuracy: 0.12
# ----------
# Epoch 32/99, current lr=0.0003
# train_loss: 0.000083, dev loss: 0.000681, accuracy: 0.12
# ----------
# Epoch 33/99, current lr=0.0003
# train_loss: 0.000080, dev loss: 0.000681, accuracy: 0.12
# ----------
# Epoch 34/99, current lr=0.0003
# train_loss: 0.000128, dev loss: 0.000658, accuracy: 0.12
# ----------
# Epoch 35/99, current lr=0.0003
# train_loss: 0.000084, dev loss: 0.000648, accuracy: 0.12
# ----------
# Epoch 36/99, current lr=0.0003
# train_loss: 0.000098, dev loss: 0.000647, accuracy: 0.12
# ----------
# Epoch 37/99, current lr=0.0003
# train_loss: 0.000097, dev loss: 0.000647, accuracy: 0.12
# ----------
# Epoch 38/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000086, dev loss: 0.000646, accuracy: 0.12
# ----------
# Epoch 39/99, current lr=0.0003
# train_loss: 0.000085, dev loss: 0.000651, accuracy: 0.12
# ----------
# Epoch 40/99, current lr=0.0003
# train_loss: 0.000095, dev loss: 0.000660, accuracy: 0.12
# ----------
# Epoch 41/99, current lr=0.0003
# train_loss: 0.000071, dev loss: 0.000670, accuracy: 0.12
# ----------
# Epoch 42/99, current lr=0.0003
# train_loss: 0.000101, dev loss: 0.000666, accuracy: 0.12
# ----------
# Epoch 43/99, current lr=0.0003
# train_loss: 0.000083, dev loss: 0.000665, accuracy: 0.12
# ----------
# Epoch 44/99, current lr=0.0003
# train_loss: 0.000071, dev loss: 0.000677, accuracy: 0.12
# ----------
# Epoch 45/99, current lr=0.0003
# train_loss: 0.000088, dev loss: 0.000682, accuracy: 0.12
# ----------
# Epoch 46/99, current lr=0.0003
# train_loss: 0.000105, dev loss: 0.000652, accuracy: 0.12
# ----------
# Epoch 47/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000100, dev loss: 0.000636, accuracy: 0.12
# ----------
# Epoch 48/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000077, dev loss: 0.000633, accuracy: 0.12
# ----------
# Epoch 49/99, current lr=0.0003
# train_loss: 0.000087, dev loss: 0.000636, accuracy: 0.12
# ----------
# Epoch 50/99, current lr=0.0003
# train_loss: 0.000078, dev loss: 0.000636, accuracy: 0.12
# ----------
# Epoch 51/99, current lr=0.0003
# train_loss: 0.000074, dev loss: 0.000637, accuracy: 0.12
# ----------
# Epoch 52/99, current lr=0.0003
# train_loss: 0.000083, dev loss: 0.000646, accuracy: 0.12
# ----------
# Epoch 53/99, current lr=0.0003
# train_loss: 0.000087, dev loss: 0.000665, accuracy: 0.12
# ----------
# Epoch 54/99, current lr=0.0003
# train_loss: 0.000079, dev loss: 0.000712, accuracy: 0.12
# ----------
# Epoch 55/99, current lr=0.0003
# train_loss: 0.000078, dev loss: 0.000779, accuracy: 0.12
# ----------
# Epoch 56/99, current lr=0.0003
# train_loss: 0.000110, dev loss: 0.000788, accuracy: 0.12
# ----------
# Epoch 57/99, current lr=0.0003
# train_loss: 0.000062, dev loss: 0.000778, accuracy: 0.12
# ----------
# Epoch 58/99, current lr=0.0003
# train_loss: 0.000083, dev loss: 0.000728, accuracy: 0.12
# ----------
# Epoch 59/99, current lr=0.0003
# train_loss: 0.000121, dev loss: 0.000660, accuracy: 0.12
# ----------
# Epoch 60/99, current lr=0.0003
# Copied best model weights!
# train_loss: 0.000117, dev loss: 0.000620, accuracy: 0.12
# ----------
# Epoch 61/99, current lr=0.0003
# train_loss: 0.000082, dev loss: 0.000637, accuracy: 0.12
# ----------
# Epoch 62/99, current lr=0.0003
# train_loss: 0.000088, dev loss: 0.000670, accuracy: 0.12
# ----------
# Epoch 63/99, current lr=0.0003
# train_loss: 0.000100, dev loss: 0.000699, accuracy: 0.11
# ----------
# Epoch 64/99, current lr=0.0003
# train_loss: 0.000096, dev loss: 0.000712, accuracy: 0.11
# ----------
# Epoch 65/99, current lr=0.0003
# train_loss: 0.000120, dev loss: 0.000702, accuracy: 0.11
# ----------
# Epoch 66/99, current lr=0.0003
# train_loss: 0.000105, dev loss: 0.000682, accuracy: 0.12
# ----------
# Epoch 67/99, current lr=0.0003
# train_loss: 0.000104, dev loss: 0.000650, accuracy: 0.12
# ----------
# Epoch 68/99, current lr=0.0003
# train_loss: 0.000097, dev loss: 0.000667, accuracy: 0.12
# ----------
# Epoch 69/99, current lr=0.0003
# train_loss: 0.000095, dev loss: 0.000707, accuracy: 0.12
# ----------
# Epoch 70/99, current lr=0.0003
# train_loss: 0.000110, dev loss: 0.000736, accuracy: 0.11
# ----------
# Epoch 71/99, current lr=0.0003
# train_loss: 0.000074, dev loss: 0.000797, accuracy: 0.11
# ----------
# Epoch 72/99, current lr=0.0003
# train_loss: 0.000111, dev loss: 0.000796, accuracy: 0.11
# ----------
# Epoch 73/99, current lr=0.0003
# train_loss: 0.000142, dev loss: 0.000747, accuracy: 0.12
# ----------
# Epoch 74/99, current lr=0.0003
# train_loss: 0.000104, dev loss: 0.000686, accuracy: 0.12
# ----------
# Epoch 75/99, current lr=0.0003
# train_loss: 0.000096, dev loss: 0.000650, accuracy: 0.12
# ----------
# Epoch 76/99, current lr=0.0003
# train_loss: 0.000113, dev loss: 0.000659, accuracy: 0.12
# ----------
# Epoch 77/99, current lr=0.0003
# train_loss: 0.000089, dev loss: 0.000706, accuracy: 0.11
# ----------
# Epoch 78/99, current lr=0.0003
# train_loss: 0.000097, dev loss: 0.000735, accuracy: 0.11
# ----------
# Epoch 79/99, current lr=0.0003
# train_loss: 0.000120, dev loss: 0.000733, accuracy: 0.11
# ----------
# Epoch 80/99, current lr=0.0003
# train_loss: 0.000088, dev loss: 0.000703, accuracy: 0.12
# ----------
# Epoch 81/99, current lr=0.0003
# Epoch    82: reducing learning rate of group 0 to 1.5000e-04.
# Loading best model weights!
# train_loss: 0.000081, dev loss: 0.000677, accuracy: 0.12
# ----------
# Epoch 82/99, current lr=0.00015
# train_loss: 0.000079, dev loss: 0.000630, accuracy: 0.12
# ----------
# Epoch 83/99, current lr=0.00015
# train_loss: 0.000113, dev loss: 0.000647, accuracy: 0.12
# ----------
# Epoch 84/99, current lr=0.00015
# train_loss: 0.000084, dev loss: 0.000677, accuracy: 0.12
# ----------
# Epoch 85/99, current lr=0.00015
# train_loss: 0.000107, dev loss: 0.000703, accuracy: 0.12
# ----------
# Epoch 86/99, current lr=0.00015
# train_loss: 0.000079, dev loss: 0.000725, accuracy: 0.12
# ----------
# Epoch 87/99, current lr=0.00015
# train_loss: 0.000087, dev loss: 0.000741, accuracy: 0.12
# ----------
# Epoch 88/99, current lr=0.00015
# train_loss: 0.000079, dev loss: 0.000751, accuracy: 0.12
# ----------
# Epoch 89/99, current lr=0.00015
# train_loss: 0.000094, dev loss: 0.000740, accuracy: 0.12
# ----------
# Epoch 90/99, current lr=0.00015
# train_loss: 0.000109, dev loss: 0.000708, accuracy: 0.12
# ----------
# Epoch 91/99, current lr=0.00015
# train_loss: 0.000054, dev loss: 0.000692, accuracy: 0.12
# ----------
# Epoch 92/99, current lr=0.00015
# train_loss: 0.000138, dev loss: 0.000662, accuracy: 0.12
# ----------
# Epoch 93/99, current lr=0.00015
# train_loss: 0.000093, dev loss: 0.000647, accuracy: 0.12
# ----------
# Epoch 94/99, current lr=0.00015
# train_loss: 0.000102, dev loss: 0.000634, accuracy: 0.12
# ----------
# Epoch 95/99, current lr=0.00015
# train_loss: 0.000080, dev loss: 0.000631, accuracy: 0.12
# ----------
# Epoch 96/99, current lr=0.00015
# train_loss: 0.000072, dev loss: 0.000634, accuracy: 0.12
# ----------
# Epoch 97/99, current lr=0.00015
# train_loss: 0.000106, dev loss: 0.000639, accuracy: 0.12
# ----------
# Epoch 98/99, current lr=0.00015
# train_loss: 0.000116, dev loss: 0.000643, accuracy: 0.12
# ----------
# Epoch 99/99, current lr=0.00015
# train_loss: 0.000089, dev loss: 0.000647, accuracy: 0.12
# ----------

# %% [markdown]
# ### 6. Let's plot the training validation's progress using the returned values, that is, loss_hist and metric_hist:

# %%
# Train validation progress
num_epochs = params_train["num_epochs"]

# plot loss progress
plt.title("Train-val Loss")
plt.plot(range(1, num_epochs+1), loss_hist["train"], label="train")
plt.plot(range(1, num_epochs + 1), loss_hist["val"], label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1, num_epochs + 1),
         metric_hist["train"],
         label="train")
plt.plot(range(1, num_epochs+1),
         metric_hist["val"],
         label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 7. By doing this, we've made sure that all the elements are implemented correctly. Let's set the flag to sanity_check: False and run the code. The training will start and we will see its progress, as shown in the following code block:

# %%
# define the training parameters and call the train_val helper function

params_train = {
    "num_epochs": 100,
    "optimizer": opt,
    "loss_func": loss_func,
    "train_dl": train_dl,
    "val_dl": val_dl,
    "sanity_check": False,
    "lr_scheduler": lr_scheduler,
    "path2weights": "./models/weights.pt",
}

# train and validate the model
cnn_model, loss_hist, metric_hist = train_val(cnn_model, params_train)
# Out:
# Epoch 0/99, current lr=1.875e-05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-178c0e7798e9> in <module>
#      13
#      14 # train and validate the model
# ---> 15 cnn_model, loss_hist, metric_hist = train_val(cnn_model, params_train)
#
# <ipython-input-56-41d7836de77f> in train_val(model, params)
#      40                                               train_dl,
#      41                                               sanity_check,
# ---> 42                                               opt)
#      43
#      44         # collect loss and metric for training dataset
#
# <ipython-input-55-7c9282ed06b9> in loss_epoch(model, loss_func, dataset_dl, sanity_check, opt)
#       4     len_data = len(dataset_dl.dataset)
#       5
# ----> 6     for xb, yb in dataset_dl:
#       7         # move batch to device
#       8         xb = xb.to(device)
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torch/utils/data/dataset.py in __getitem__(self, idx)
#     255
#     256     def __getitem__(self, idx):
# --> 257         return self.dataset[self.indices[idx]]
#     258
#     259     def __len__(self):
#
# <ipython-input-13-a39b7646cf62> in __getitem__(self, idx)
#      31         # open image, apply transforms and return with label
#      32         image = Image.open(self.full_filenames[idx]) # PIL image
# ---> 33         image = self.transform(image)
#      34         return image, self.labels[idx]
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      68     def __call__(self, img):
#      69         for t in self.transforms:
# ---> 70             img = t(img)
#      71         return img
#      72
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, pic)
#      99             Tensor: Converted image.
#     100         """
# --> 101         return F.to_tensor(pic)
#     102
#     103     def __repr__(self):
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/torchvision/transforms/functional.py in to_tensor(pic)
#      85         img = 255 * torch.from_numpy(np.array(pic, np.uint8, copy=False))
#      86     else:
# ---> 87         img = torch.ByteTensor(torch.ByteStorage.from_buffer(pic.tobytes()))
#      88     # PIL image mode: L, LA, P, I, F, RGB, YCbCr, RGBA, CMYK
#      89     if pic.mode == 'YCbCr':
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/PIL/Image.py in tobytes(self, encoder_name, *args)
#     699             args = self.mode
#     700
# --> 701         self.load()
#     702
#     703         # unpack data
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/PIL/TiffImagePlugin.py in load(self)
#    1069         if self.use_load_libtiff:
#    1070             return self._load_libtiff()
# -> 1071         return super().load()
#    1072
#    1073     def load_end(self):
#
# ~/anaconda3/envs/test_env/lib/python3.6/site-packages/PIL/ImageFile.py in load(self)
#     231                         while True:
#     232                             try:
# --> 233                                 s = read(self.decodermaxblock)
#     234                             except (IndexError, struct.error):
#     235                                 # truncated png/gif
#
# KeyboardInterrupt:

# %%
# Train validation progress
num_epochs = params_train["num_epochs"]

# plot loss progress
plt.title("Train-val Loss")
plt.plot(range(1, num_epochs+1), loss_hist["train"], label="train")
plt.plot(range(1, num_epochs + 1), loss_hist["val"], label="val")
plt.ylabel("Loss")
plt.xlabel("Training Epochs")
plt.legend()
plt.show()

# plot accuracy progress
plt.title("Train-Val Accuracy")
plt.plot(range(1, num_epochs + 1),
         metric_hist["train"],
         label="train")
plt.plot(range(1, num_epochs+1),
         metric_hist["val"],
         label="val")
plt.ylabel("Accuracy")
plt.xlabel("Training Epochs")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Deploying the model

# %% [markdown]
# ### 1. First, we'll create an object of the Net class and load the stored weights into the model:

# %%
# model parameters
params_model = {
    "input_shape": (3, 96, 96),
    "initial_filters": 8,
    "num_fc1": 100,
    "dropout_rate": 0.25,
    "num_classes": 2,
}

# initialize model
cnn_model = Net(params_model)

# %% [markdown]
# ### 2. Let's load state_dict into the model:

# %%
# load state_dict into model
path2weights = "./models/weights.pt"
cnn_model.load_state_dict(torch.load(path2weights))
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### 3. Set the model in eval mode:

# %%
# set model in evaluation mode
cnn_model.eval()
# Out:
# Net(
#   (conv1): Conv2d(3, 8, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(8, 16, kernel_size=(3, 3), stride=(1, 1))
#   (conv3): Conv2d(16, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (fc1): Linear(in_features=1024, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=2, bias=True)
# )

# %% [markdown]
# ### 4. Move the model onto a CUDA device if one's available:

# %%
# move model to cuda/gpu device
if torch.cuda.is_available():
    device = torch.device("cuda")
    cnn_model = cnn_model.to(device)

# %% [markdown]
# ### 5. Let's develop a helper function to deploy the model on a dataset:

# %%
# define the deploy_model function
import time
def deploy_model(model, dataset, device, num_classes=2,
                 sanity_check=False):
    len_data = len(dataset)
    # initialize output tensor on CPU: due to GPU memory limits
    y_out = torch.zeros(len_data, num_classes)
    # initialize ground trugh on CPU: due to GPU memory limits
    y_gt = np.zeros((len_data), dtype="uint8")
    # move model to device
    model = model.to(device)
    
    elapsed_times = []
    with torch.no_grad():
        for i in range(len_data):
            x, y = dataset[i]
            y_gt[i] = y
            start = time.time()
            y_out[i] = model(x.unsqueeze(0).to(device))
            elapsed = time.time() - start
            elapsed_times.append(elapsed)
            
            if sanity_check is True:
                break
        
    inference_time = np.mean(elapsed_times) * 1000
    print("average inference time per image on %s: %.2f ms"
         % (device, inference_time))
    return y_out.numpy(), y_gt

# %% [markdown]
# ### 6. Let's use this function to deploy the model on the validation dataset:

# %%
# deploy model
y_out, y_gt = deploy_model(cnn_model, val_ds, device=device,
                           sanity_check=False)
print(y_out.shape, y_gt.shape)
# Out:
# average inference time per image on cuda: 0.48 ms
# (44005, 2) (44005,)

# %% [markdown]
# ### 7. Let's calculate the accuracy of the model on the validation dataset using the predicted outputs:

# %%
from sklearn.metrics import accuracy_score

# get predictions
y_pred = np.argmax(y_out, axis=1)
print(y_pred.shape, y_gt.shape)

# compute accuracy
acc = accuracy_score(y_pred, y_gt)
print("accuracy: %.2f" % acc)
# Out:
# (44005,) (44005,)
# accuracy: 0.78
